# %%
import sys
sys.path.append("../src")  # adjust relative path if needed

import pandas as pd
from best_library.cleaning_data import load_data, split_data, clean_data
from best_library.features import encode_features
from best_library.model import train_model, predict
from best_library.evaluation import compute_roc_auc

# %%
# ## 2. Load and inspect data

file_path = "../sample_diabetes_mellitus_data.csv"

df = load_data(file_path)
print("Raw data shape:", df.shape)
df.head()
# Out:
# Raw data shape: (10000, 53)
#    Unnamed: 0  encounter_id  hospital_id   age        bmi  elective_surgery  \
# 0           0        214826          118  68.0  22.732803                 0
# 1           1        246060           81  77.0  27.421875                 0
# 2           2        276985          118  25.0  31.952749                 0
# 3           3        262220          118  81.0  22.635548                 1
# 4           4        201746           33  19.0        NaN                 0
#
#    ethnicity gender  height hospital_admit_source  ... ventilated_apache  \
# 0  Caucasian      M   180.3                 Floor  ...                 0
# 1  Caucasian      F   160.0                 Floor  ...                 1
# 2  Caucasian      F   172.7  Emergency Department  ...                 0
# 3  Caucasian      F   165.1        Operating Room  ...                 1
# 4  Caucasian      M   188.0                   NaN  ...                 0
#
#    wbc_apache aids cirrhosis  hepatic_failure  immunosuppression  leukemia  \
# 0        14.1    0         0                0                  0         0
# 1        12.7    0         0                0                  0         0
# 2         NaN    0         0                0                  0         0
# 3         8.0    0         0                0                  0         0
# 4         NaN    0         0                0                  0         0
#
#    lymphoma  solid_tumor_with_metastasis  diabetes_mellitus
# 0         0                            0                  1
# 1         0                            0                  1
# 2         0                            0                  0
# 3         0                            0                  0
# 4         0                            0                  0
#
# [5 rows x 53 columns]

# %%
# ## 3. Split the data into train and test

train_df, test_df = split_data(df)

print(f"Train size: {train_df.shape}")
print(f"Test size: {test_df.shape}")
# Out:
# Train size: (8000, 53)
# Test size: (2000, 53)

# %%
# ## 4. Clean data

train_df = clean_data(train_df)
test_df = clean_data(test_df)

print("After cleaning:")
print(f"Train size: {train_df.shape}")
print(f"Test size: {test_df.shape}")
# Out:
# After cleaning:
# Train size: (7494, 53)
# Test size: (1874, 53)
# /Users/felipe/Documents/BSE/Term-1/Computing_for_Data_Science/hw4/CFDS-HW4/notebooks/../src/best_library/cleaning_data.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].fillna(df[col].mean())

# %%
# ## 5. Encode features

train_df = encode_features(train_df)
test_df = encode_features(test_df)

train_df.head()
# Out:
#       Unnamed: 0  encounter_id  hospital_id   age        bmi  \
# 9254        9254        185898          137  88.0  28.713767
# 1561        1561        179718           83  69.0        NaN
# 1670        1670        204365          118  61.0        NaN
# 6087        6087        167361          118  36.0  33.861606
# 6669        6669        213013           83  49.0  22.693954
#
#       elective_surgery gender  height hospital_admit_source  \
# 9254                 0      F  157.48  Emergency Department
# 1561                 0      F  152.40                 Floor
# 1670                 0      M  188.00                   NaN
# 6087                 1      F  165.10        Operating Room
# 6669                 1      F  162.60        Operating Room
#
#                icu_admit_source  ...  leukemia lymphoma  \
# 9254       Accident & Emergency  ...         1        0
# 1561                      Floor  ...         0        0
# 1670       Accident & Emergency  ...         0        0
# 6087  Operating Room / Recovery  ...         0        0
# 6669  Operating Room / Recovery  ...         0        0
#
#      solid_tumor_with_metastasis  diabetes_mellitus  gender_binary  \
# 9254                           0                  1              0
# 1561                           0                  1              0
# 1670                           0                  0              1
# 6087                           0                  0              0
# 6669                           0                  0              0
#
#       ethnicity_Asian  ethnicity_Caucasian  ethnicity_Hispanic  \
# 9254            False                 True               False
# 1561            False                 True               False
# 1670            False                 True               False
# 6087            False                False               False
# 6669            False                 True               False
#
#       ethnicity_Native American  ethnicity_Other/Unknown
# 9254                      False                    False
# 1561                      False                    False
# 1670                      False                    False
# 6087                      False                    False
# 6669                      False                    False
#
# [5 rows x 58 columns]

# %%
# ## 6. Define feature set and target

target = "diabetes_mellitus"
features = [
    "age", "height", "weight", "aids", "cirrhosis", "hepatic_failure",
    "immunosuppression", "leukemia", "lymphoma", "solid_tumor_with_metastasis",
    "gender_binary"
]

# include ethnicity dummies dynamically
ethnicity_cols = [col for col in train_df.columns if col.startswith("ethnicity_")]
features += ethnicity_cols

print("Features used for modeling:")
print(features)
# Out:
# Features used for modeling:
# ['age', 'height', 'weight', 'aids', 'cirrhosis', 'hepatic_failure', 'immunosuppression', 'leukemia', 'lymphoma', 'solid_tumor_with_metastasis', 'gender_binary', 'ethnicity_Asian', 'ethnicity_Caucasian', 'ethnicity_Hispanic', 'ethnicity_Native American', 'ethnicity_Other/Unknown']

# %%
# ## 7. Train model

model = train_model(train_df[features], train_df[target], model_type='logistic')

# %%
# ## 8. Predict probabilities for train and test sets

train_df, test_df = predict(model, train_df, test_df, features)


train_df[["diabetes_mellitus", "predictions"]].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # ## 8. Predict probabilities for train and test sets
# ----> 3 train_df, test_df = predict(model, train_df, test_df)
#       5 train_df[["diabetes_mellitus", "predictions"]].head()
#
# File ~/Documents/BSE/Term-1/Computing_for_Data_Science/hw4/CFDS-HW4/notebooks/../src/best_library/model.py:15, in predict(model, X_train, X_test)
#      14 def predict(model, X_train, X_test):
# ---> 15     X_train['predictions'] = model.predict_proba(X_train)[:, 1]
#      16     X_test['predictions'] = model.predict_proba(X_test)[:, 1]
#      17     return X_train, X_test
#
# File ~/Documents/BSE/Term-1/Computing_for_Data_Science/hw4/CFDS-HW4/.venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1462, in LogisticRegression.predict_proba(self, X)
#    1457 ovr = self.multi_class in ["ovr", "warn"] or (
#    1458     self.multi_class in ["auto", "deprecated"]
#    1459     and (self.classes_.size <= 2 or self.solver == "liblinear")
#    1460 )
#    1461 if ovr:
# -> 1462     return super()._predict_proba_lr(X)
#    1463 else:
#    1464     decision = self.decision_function(X)
#
# File ~/Documents/BSE/Term-1/Computing_for_Data_Science/hw4/CFDS-HW4/.venv/lib/python3.11/site-packages/sklearn/linear_model/_base.py:390, in LinearClassifierMixin._predict_proba_lr(self, X)
#     383 def _predict_proba_lr(self, X):
#     384     """Probability estimation for OvR logistic regression.
#     385
#     386     Positive class probabilities are computed as
#     387     1. / (1. + np.exp(-self.decision_function(X)));
#     388     multiclass is handled by normalizing that over all classes.
#     389     """
# --> 390     prob = self.decision_function(X)
#     391     expit(prob, out=prob)
#     392     if prob.ndim == 1:
#
# File ~/Documents/BSE/Term-1/Computing_for_Data_Science/hw4/CFDS-HW4/.venv/lib/python3.11/site-packages/sklearn/linear_model/_base.py:352, in LinearClassifierMixin.decision_function(self, X)
#     349 check_is_fitted(self)
#     350 xp, _ = get_namespace(X)
# --> 352 X = validate_data(self, X, accept_sparse="csr", reset=False)
#     353 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     354 return (
#     355     xp.reshape(scores, (-1,))
#     356     if (scores.ndim > 1 and scores.shape[1] == 1)
#     357     else scores
#     358 )
#
# File ~/Documents/BSE/Term-1/Computing_for_Data_Science/hw4/CFDS-HW4/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2929, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2845 def validate_data(
#    2846     _estimator,
#    2847     /,
#    (...)   2853     **check_params,
#    2854 ):
#    2855     """Validate input data and set or check feature names and counts of the input.
#    2856
#    2857     This helper function should be used in an estimator that requires input
#    (...)   2927         validated.
#    2928     """
# -> 2929     _check_feature_names(_estimator, X, reset=reset)
#    2930     tags = get_tags(_estimator)
#    2931     if y is None and tags.target_tags.required:
#
# File ~/Documents/BSE/Term-1/Computing_for_Data_Science/hw4/CFDS-HW4/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Unnamed: 0
# - albumin_apache
# - apache_2_diagnosis
# - apache_3j_diagnosis
# - apache_post_operative
# - ...

# %%
# ## 9. Evaluate model using ROC-AUC

train_auc = compute_roc_auc(train_df[target], train_df["predictions"])
test_auc = compute_roc_auc(test_df[target], test_df["predictions"])

print(f"Train ROC-AUC: {train_auc:.3f}")
print(f"Test ROC-AUC:  {test_auc:.3f}")
